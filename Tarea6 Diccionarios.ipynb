# %% [markdown]
# Ejercicio 1
# Crea un programa que pida un número entero positivo por teclado y que cree un diccionario cuyas claves
# sean desde el número 1 hasta el número indicado. Los valores de cada clave serán las propias claves elevadas
# al cubo.

# %%
n = int(input("Introduzca un número entero positivo: "))
dic = {}
for i in range(1,n+1):
  dic[i] = i**3
print(dic)
# Out:
# Introduzca un número entero positivo: 4
# {1: 1, 2: 8, 3: 27, 4: 64}

# %% [markdown]
# Ejercicio 2
# Escribe un programa que pregunte al usuario su nombre, edad y teléfono y lo guarde en un diccionario.
# Después, debe mostrar por pantalla el mensaje ‘{nombre} tiene {edad} años y su número de teléfono es
# {teléfono}.

# %%
dic = {}
nombre = input("Introduzca su nombre: ")
edad = int(input("Introduzca su edad: "))
telefono = int(input("Introduzca su número telefónico: "))
dic = {"nombre" : nombre,
       "edad" : edad,
       "telefono" : telefono}
print("{} tiene {} años y su número de teléfono es {}.". format(dic["nombre"], dic["edad"], dic["telefono"]))
# Out:
# Introduzca su nombre: ivan
# Introduzca su edad: 23
# Introduzca su número telefónico: 334343
# ivan tiene 23 años y su número de teléfono es 334343.

# %% [markdown]
# Escribe un programa que cree un diccionario simulando una cesta de la compra. El programa debe preguntar
# el artículo y su precio por unidad. El artículo será la clave y el valor el precio, hasta que el usuario decida
# terminar. Después se debe mostrar por pantalla la lista de la compra y el coste total.

# %%
dic = {}
suma = 0
while 1<3 :
  articulo = input("Introduzca el nombre del artículo: ")
  precio = int(input("Introduzca el precio del artículo: "))
  dic [articulo] = precio
  suma += precio
  s = input("Si desea finalizar la lista ingrese 'terminar' de lo contrario de enter: ")
  if s == "terminar":
    break
dic["Total"] = suma
print("-------------------------------")
for clave in dic:
  espacio = 20 - len(clave)
  print(clave, " "*espacio, dic[clave])
print("-------------------------------")
# Out:
# Introduzca el nombre del artículo: leche
# Introduzca el precio del artículo: 12
# Si desea finalizar la lista ingrese 'terminar' de lo contrario de enter:
# Introduzca el nombre del artículo: spaguetti
# Introduzca el precio del artículo: 4
# Si desea finalizar la lista ingrese 'terminar' de lo contrario de enter:
# Introduzca el nombre del artículo: garrafon de agua
# Introduzca el precio del artículo: 20
# Si desea finalizar la lista ingrese 'terminar' de lo contrario de enter:
# Introduzca el nombre del artículo: ajo
# Introduzca el precio del artículo: 1234
# Si desea finalizar la lista ingrese 'terminar' de lo contrario de enter: terminar
# -------------------------------
# leche                 12
# spaguetti             4
# garrafon de agua      20
# ajo                   1234
# Total                 1270
# -------------------------------

# %% [markdown]
# Ejercicio 4
# Crea un programa que lea números enteros hasta que introduzca el 0 y devuelva un diccionario con la
# cantidad números positivos y negativos introducidos.

# %%
dic = {"positivos": [],
       "negativos": []
       }
num = int(input())
while num != 0:
  if num > 0 :
    dic["positivos"].append(num)
  else:
    dic["negativos"].append(num)
  num = int(input())
print(dic)
# Out:
# 1
# 10
# 3
# -2
# -1
# -40
# -5
# -0
# {'positivos': [1, 10, 3], 'negativos': [-2, -1, -40, -5]}

# %% [markdown]
# Ejercicio 5
# Crea un programa que lea números enteros hasta que introduzca el 0 y devuelva un diccionario con la
# cantidad números pares e impares introducidos.

# %%
dic = {"pares": [],
       "impares": []
       }
num = int(input())
while num != 0:
  if num%2 == 0 :
    dic["pares"].append(num)
  else:
    dic["impares"].append(num)
  num = int(input())
print("La cantidad de números pares es {} y la cantidad de números impares es {}.".format(len(dic["pares"]), len(dic["impares"])))
# Out:
# 1
# 2
# 3
# 22
# 10
# 5
# 0
# La cantidad de números pares es 3 y la cantidad de números impares es 3.

# %% [markdown]
# Ejercicio 6
# Crea un programa que permita al usuario introducir los nombres de los alumnos de una clase y las notas que
# han obtenido. Cada alumno puede tener distinta cantidad de notas. Guarda la información en un diccionario
# cuyas claves serán los nombres de los alumnos y los valores serán listas con las notas de cada alumno.
# El programa va a pedir el nombre de un estudiante e irá pidiendo sus notas (del 1 al 10) hasta que introduzcamos un 0. Al final, cuando el nombre que introduzcamos sea un string vacío, el programa nos mostrará la
# lista de alumnos y la nota media obtenida por cada uno de ellos.
# PISTA: Vas a necesitar la función sum().

# %%
clase = {}
lista = {}
print("Introduzca el nombre del alumno, para terminar el registro de enter: ")
nombre = input()
while nombre != "":
  clase[nombre]=[]
  suma = 0
  print("Ingrese las calificaciones del alumno, para terinar ingrese cero:")
  calif = int(input())
  while calif != 0:
    suma += calif
    clase[nombre].append(calif)
    calif = int(input())
  lista[nombre]= suma/len(clase[nombre])
  print("Introduzca el nombre del alumno, para terminar el registro de enter: ")
  nombre = input()
print(lista)
# Out:
# Introduzca el nombre del alumno, para terminar el registro de enter:
# ivan
# Ingrese las calificaciones del alumno, para terinar ingrese cero:
# 10
# 9
# 8
# 0
# Introduzca el nombre del alumno, para terminar el registro de enter:
# maria
# Ingrese las calificaciones del alumno, para terinar ingrese cero:
# 8
# 8
# 8
# 0
# Introduzca el nombre del alumno, para terminar el registro de enter:
# jose
# Ingrese las calificaciones del alumno, para terinar ingrese cero:
# 5
# 0
# Introduzca el nombre del alumno, para terminar el registro de enter:
#
# {'ivan': [10, 9, 8], 'maria': [8, 8, 8], 'jose': [5]}
# {'ivan': 9.0, 'maria': 8.0, 'jose': 5.0}

# %% [markdown]
# Ejercicio 7
# Crea un programa que pida un número entero positivo por teclado y que cree un diccionario cuyas claves
# sean desde el número 1 hasta el número indicado. Los valores de cada clave serán tantos símbolos "*" como
# indique la clave.

# %%
dic = {}
n = int(input("Ingrese un número positivo: "))
for i in range(1,n+1):
  dic[i] = "*"*i
print(dic)
# Out:
# Ingrese un número positivo: 5
# {1: '*', 2: '**', 3: '***', 4: '****', 5: '*****'}

# %% [markdown]
# Ejercicio 8
# Crea un programa que pida el número de palabras a introducir. Crear un diccionario de clave la palabra y
# de valor la longitud de dicha palabra.

# %%
dic = {}
n = int(input("Ingrese el número de palabras a introducir: "))
for _ in range(n):
  palabra = input("Ingrese la palabra al diccionario: ")
  dic[palabra] = len(palabra)
print(dic)
# Out:
# Ingrese el número de palabras a introducir: 3
# Ingrese la palabra al diccionario: hola
# Ingrese la palabra al diccionario: ferrocarril
# Ingrese la palabra al diccionario: ivan
# {'hola': 4, 'ferrocarril': 11, 'ivan': 4}

# %% [markdown]
# Ejercicio 9
# Crea un programa que pida el número de palabras a introducir. Crear un diccionario de clave la palabra y
# de valor el número de vocales de la palabra.

# %%
dic = {}
n = int(input("Ingrese el número de palabras a introducir: "))
for _ in range(n):
  palabra = input("Ingrese la palabra al diccionario: ")
  dic[palabra] = palabra.count('a') + palabra.count('e') + palabra.count('i')+palabra.count('o')+palabra.count('u')
print(dic)
# Out:
# Ingrese el número de palabras a introducir: 3
# Ingrese la palabra al diccionario: lala
# Ingrese la palabra al diccionario: jklmnopqrst
# Ingrese la palabra al diccionario: a
# {'lala': 2, 'jklmnopqrst': 1, 'a': 1}

# %% [markdown]
# Ejercicio 10
# Dada una matriz, crea un diccionario que guarde el número de filas, el de columnas y cada fila en una entrada
# de un diccionario

# %%
import numpy as np
dic = {}
M = np.ones((int(input("Introduzca el número de filas: ")), int(input("introduzca el número de columnas: "))))*2
for i in range(1,len(M)+1):
  dic["fila "+str(i)] = M[i-1]
print(dic)
# Out:
# Introduzca el número de filas: 3
# introduzca el número de columnas: 2
# {'fila 1': array([2., 2.]), 'fila 2': array([2., 2.]), 'fila 3': array([2., 2.])}
