# %% [markdown]
# Ejercicio 1
# Pide al usuario el número de números enteros que va a introducir por teclado. Para cada uno de esos
# números, crea una tupla donde la primera entrada sea el número entero y, la segunda, la palabra “par” o
# “impar” según la paridad del número entero. Muestra la tupla recién creada al usuario.

# %%
n = int(input("Introduzca la cantidad de números que va a introducir: "))
for _ in range(n):
  numero = int(input())
  if numero % 2== 0:
    tupla = numero, "par"
    print(tupla)
  else:
    tupla = numero, "impar"
    print(tupla)
# Out:
# Introduzca la cantidad de números que va a introducir: 1
# 3
# (3, 'impar')
# <class 'tuple'>

# %% [markdown]
# Ejercicio 2
# Dado un año proporcionado por el usuario, crea una tupla de dos elementos cuya primera entrada sea el año
# y, la segunda entrada, el horóscopo chino correspondiente.

# %%
año = int(input("Introduzca un año: "))

rata =[1936, 1948, 1960, 1972, 1984, 1996, 2008, 2020]
buey = [1937, 1949, 1961, 1973, 1985, 1997, 2009, 2021]
tigre =[938, 1950, 1962, 1974, 1986, 1998, 2010]
conejo = [1939, 1951, 1963, 1975, 1987, 1999, 2011]
dragon = [1940, 1952, 1964, 1976, 1988, 2000, 2012]
serpiente = [1941, 1953, 1965, 1977, 1989, 2001, 2013]
caballo = [1942, 1954, 1966, 1978, 1990, 2002, 2014]
cabra = [1943, 1955, 1967, 1979, 1991, 2003, 2015]
mono = [1944, 1956, 1968, 1980, 1992, 2004, 2016]
gallo = [1945, 1957, 1969, 1981, 1993, 2005, 2017]
perro = [1946, 1958, 1970, 1982, 1994, 2006, 2018]
cerdo = [1947, 1959, 1971, 1983, 1995, 2007, 2019]

if año in rata:
  print((año, "rata"))
elif año in buey: 
  print((año, "buey"))
elif año in tigre: 
  print((año, "tigre"))
elif año in conejo: 
  print((año, "conejo"))
elif año in dragon: 
  print((año, "dragón"))
elif año in serpiente: 
  print((año, "serpiente"))
elif año in caballo: 
  print((año, "caballo"))
elif año in cabra: 
  print((año, "cabra"))
elif año in mono: 
  print((año, "mono"))
elif año in gallo: 
  print((año, "gallo"))
elif año in perro: 
  print((año, "perro"))
elif año in cerdo: 
  print((año, "cerdo"))
else:
  print("Número no encontrado.")
# Out:
# Introduzca un año: 1992
# (1992, 'mono')

# %% [markdown]
# Ejercicio 3
# Dada una frase proporcionada por el usuario, crea una lista de tuplas indicando palabra, longitud de cada
# palabra, letra inicial y posición que ocupan dentro de la frase.

# %%
frase = input("frase: ")
prhase = frase
frase = frase.split()
lista = []
pos = 0
for palabra in frase:
  longitud = len(palabra)
  tupla = (palabra, longitud, palabra[0], pos)
  lista.append(tupla)
  pos += longitud + 1
print(lista)
# Out:
# frase: el perro ladra fuerte
# [('el', 2, 'e', 0), ('perro', 5, 'p', 3), ('ladra', 5, 'l', 9), ('fuerte', 6, 'f', 15)]

# %% [markdown]
# Ejercicio 4
# Haz que el usuario introduzca palabras hasta que introduzca una palabra vacía. Guarda todas las palabras
# en una tupla y muestra la primera y la última introducidas haciendo uso del método unpacking.
# PISTA: Para guardar los elementos de uno en uno vas a tener que utilizar un tipo de dato que no es tupla
# y luego transformarlo a tupla.

# %%
print("Introduzca una palabra, para finalizar no introduzca algo y de enter: ")
palabra = input()
lista = []
while palabra != "":
  lista.append(palabra)
  palabra = input()
tupla = tuple(lista)
(primera, *_, ultima) = tupla
print("La primera palabra introducida es {} y la última es {}.".format(primera, ultima))
# Out:
# Introduzca una palabra, para finalizar no introduzca algo y de enter:
# Hola
# esto
# solo
# es
# una
# prueba
#
# La primera palabra introducida es Hola y la última es prueba.

# %% [markdown]
# Ejercicio 5
# Dada una lista de palabras, crea otra lista del mismo tamaño que guarde la longitud de cada palabra. Usa
# la función zip() para crear un diccionario con claves las palabras y valores, su longitud.

# %%
lista1 = ["el", "perrito", "esta", "muy", "panzon"]
lista2 = [len(lista1[0]), len(lista1[1]), len(lista1[2]), len(lista1[3]), len(lista1[4])]
items = zip(lista1, lista2)
dict(items)
# Out:
# {'el': 2, 'esta': 4, 'muy': 3, 'panzon': 6, 'perrito': 7}

# %% [markdown]
# Ejercicio 6
# Haz que el usuario introduzca palabras hasta que introduzca una palabra vacía. Guarda todas las palabras
# en una tupla y muestra la tupla y el número total de caracteres que ha introducido.
# PISTA: Para guardar los elementos de uno en uno vas a tener que utilizar un tipo de dato que no es tupla
# y luego transformarlo a tupla.

# %%
print("Introduzca una palabra, para finalizar no introduzca algo y de enter: ")
palabra = input()
lista = []
suma = 0
while palabra != "":
  suma += len(palabra)
  lista.append(palabra)
  palabra = input()
tupla = tuple(lista)
print("La tupla es {} y el número de caracteres introducidos es {}.".format(tupla, suma))
# Out:
# Introduzca una palabra, para finalizar no introduzca algo y de enter:
# hola
# crayoli
# adios
#
# La tupla es ('hola', 'crayoli', 'adios') y el número de caracteres introducidos es 16

# %% [markdown]
# Ejercicio 7
# Crea una lista de 20 tuplas de tamaño 2. La primera entrada será un número entero entre 1 y 20 y la segunda
# entrada contendrá una lista con los 10 primeros múltiplos del número entero correspondiente. Por último,
# muestra las tablas de multiplicar del 1 al 20 con el formato “1 x 1 = 1”.

# %%
tabla = []
num = []

for i in range(1,21):
  num.append(i)
  tabla.append([])
  for j in range(1,11):
    tabla[i - 1].append(i*j)
items = zip(num, tabla)

for num, tabla in items:
  print("===La tabla del {} es: ".format(num))
  i=1
  for elemento in tabla:
    print("{} x {} = {}".format(num, i, elemento))
    i += 1
# Out:
# ===La tabla del 1 es:
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 1 x 9 = 9
# 1 x 10 = 10
# ===La tabla del 2 es:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
# ===La tabla del 3 es:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
# ===La tabla del 4 es:
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40
# ===La tabla del 5 es:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
# ===La tabla del 6 es:
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60
# ===La tabla del 7 es:
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
# ===La tabla del 8 es:
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
# 8 x 10 = 80
# ===La tabla del 9 es:
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# 9 x 10 = 90
# ===La tabla del 10 es:
# 10 x 1 = 10
# 10 x 2 = 20
# 10 x 3 = 30
# 10 x 4 = 40
# 10 x 5 = 50
# 10 x 6 = 60
# 10 x 7 = 70
# 10 x 8 = 80
# 10 x 9 = 90
# 10 x 10 = 100
# ===La tabla del 11 es:
# 11 x 1 = 11
# 11 x 2 = 22
# 11 x 3 = 33
# 11 x 4 = 44
# 11 x 5 = 55
# 11 x 6 = 66
# 11 x 7 = 77
# 11 x 8 = 88
# 11 x 9 = 99
# 11 x 10 = 110
# ===La tabla del 12 es:
# 12 x 1 = 12
# 12 x 2 = 24
# 12 x 3 = 36
# 12 x 4 = 48
# 12 x 5 = 60
# 12 x 6 = 72
# 12 x 7 = 84
# 12 x 8 = 96
# 12 x 9 = 108
# 12 x 10 = 120
# ===La tabla del 13 es:
# 13 x 1 = 13
# 13 x 2 = 26
# 13 x 3 = 39
# 13 x 4 = 52
# 13 x 5 = 65
# 13 x 6 = 78
# 13 x 7 = 91
# 13 x 8 = 104
# 13 x 9 = 117
# 13 x 10 = 130
# ===La tabla del 14 es:
# 14 x 1 = 14
# 14 x 2 = 28
# 14 x 3 = 42
# 14 x 4 = 56
# 14 x 5 = 70
# 14 x 6 = 84
# 14 x 7 = 98
# 14 x 8 = 112
# 14 x 9 = 126
# 14 x 10 = 140
# ===La tabla del 15 es:
# 15 x 1 = 15
# 15 x 2 = 30
# 15 x 3 = 45
# 15 x 4 = 60
# 15 x 5 = 75
# 15 x 6 = 90
# 15 x 7 = 105
# 15 x 8 = 120
# 15 x 9 = 135
# 15 x 10 = 150
# ===La tabla del 16 es:
# 16 x 1 = 16
# 16 x 2 = 32
# 16 x 3 = 48
# 16 x 4 = 64
# 16 x 5 = 80
# 16 x 6 = 96
# 16 x 7 = 112
# 16 x 8 = 128
# 16 x 9 = 144
# 16 x 10 = 160
# ===La tabla del 17 es:
# 17 x 1 = 17
# 17 x 2 = 34
# 17 x 3 = 51
# 17 x 4 = 68
# 17 x 5 = 85
# 17 x 6 = 102
# 17 x 7 = 119
# 17 x 8 = 136
# 17 x 9 = 153
# 17 x 10 = 170
# ===La tabla del 18 es:
# 18 x 1 = 18
# 18 x 2 = 36
# 18 x 3 = 54
# 18 x 4 = 72
# 18 x 5 = 90
# 18 x 6 = 108
# 18 x 7 = 126
# 18 x 8 = 144
# 18 x 9 = 162
# 18 x 10 = 180
# ===La tabla del 19 es:
# 19 x 1 = 19
# 19 x 2 = 38
# 19 x 3 = 57
# 19 x 4 = 76
# 19 x 5 = 95
# 19 x 6 = 114
# 19 x 7 = 133
# 19 x 8 = 152
# 19 x 9 = 171
# 19 x 10 = 190
# ===La tabla del 20 es:
# 20 x 1 = 20
# 20 x 2 = 40
# 20 x 3 = 60
# 20 x 4 = 80
# 20 x 5 = 100
# 20 x 6 = 120
# 20 x 7 = 140
# 20 x 8 = 160
# 20 x 9 = 180
# 20 x 10 = 200

# %% [markdown]
# Ejercicio 8
# Pide al usuario dos números enteros por teclado. Asegúrate de que el primero es mayor o igual al segundo. Realiza la división entera y guarda en una tupla el dividendo, el divisor, el cociente y el resto de la divisón entera realizada y muéstrale al usuario el resultado por pantalla.

# %%
num1 = int(input("Ingrese el primer número: "))
num2 = int(input("Ingrese el segundo número: "))
if num1 >= num2:
 dividendo = num1 // num2
 tupla = (num1, num2, num1//num2, num1%num2)
 print(tupla)
else:
  print("Introduzca los números de tal forma que el primero es mayor que el segundo.")
# Out:
# Ingrese el primer número: 120
# Ingrese el segundo número: 14
# (120, 14, 8, 8)

# %% [markdown]
# Ejercicio 9
# Pide al usuario números entre 0 y 360. Para cada número, crea una tupla donde la primera entrada sea dicho número y, la segunda, la medida angular correspondiente en radianes. Recuerda, 360◦ = 2πrad. En este caso, utiliza π = 3.141592653589793

# %%
num = int(input())
pi = 3.141592653589793
rad = num*pi/180
print((num, rad))
# Out:
# 360
# (360, 6.283185307179586)

# %% [markdown]
# Ejercicio 10
# Pide al usuario números complejos. Para cada número, crea una tupla donde la primera entrada sea dicho número complejo, la segunda, su opuesto y, la tercera, su conjugado.

# %%
complejo = complex(input("introduzca un número complejo: "))
while complejo != 0:
  print((complejo, -complejo, complejo.conjugate()))
  complejo = complex(input())
# Out:
# introduzca un número complejo: 2+1j
# ((2+1j), (-2-1j), (2-1j))
# 4-5j
# ((4-5j), (-4+5j), (4+5j))
# 0
