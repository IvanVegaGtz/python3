# %% [markdown]
# # Ejercicio 1
# Crea un dataframe con 15 filas y 2 columnas. La primera columna se llamará x, la segunda y. Cada entrada
# será un número real a tu elección. Guarda el dataframe en una variable llamada points.

# %%
import pandas as pd
import numpy as np

# %%
x = np.random.randint(-100,100, size=(15))
y = np.random.randint(-100,100, size=(15))
points = pd.DataFrame()
points['x'] = x
points['y'] =y
points
# Out:
#      x   y
# 0  -68  51
# 1   25  44
# 2   98 -14
# 3   16 -34
# 4  -38  40
# 5  -80 -70
# 6   47  78
# 7  -15 -23
# 8   50  99
# 9   17 -13
# 10  64 -68
# 11 -27 -59
# 12 -70  44
# 13  93 -83
# 14 -56  45

# %% [markdown]
# #Ejercicio 2
# Del dataset points, muestra las filas cuyo valor en la columna x sea positivo.

# %%
points[points['x']  > 0 ]
# Out:
#      x   y
# 1   25  44
# 2   98 -14
# 3   16 -34
# 6   47  78
# 8   50  99
# 9   17 -13
# 10  64 -68
# 13  93 -83

# %% [markdown]
# # Ejercicio 3
# Del dataset points, muestra las filas cuyo valor en la columna y sea negativo. Usa el método .query().

# %%
points.query('y < 0')
# Out:
#      x   y
# 2   98 -14
# 3   16 -34
# 5  -80 -70
# 7  -15 -23
# 9   17 -13
# 10  64 -68
# 11 -27 -59
# 13  93 -83

# %% [markdown]
# # Ejercicio 4
# Del dataset points, muestra las observaciones cuyos puntos (x, y) pertenezcan al primer cuadrante. Usa el
# método .query().

# %%
points.query('x>0 and y>0')
# Out:
#     x   y
# 1  25  44
# 6  47  78
# 8  50  99

# %% [markdown]
# # Ejercicio 5
# Del dataset points, muestra las observaciones de la forma: “El punto ({x}, {y}) {no/sí} pertenece al primer
# cuadrante”.

# %%
for i, j in points.iterrows():
  if j[0] > 0 and j[1]>0:
    print('El punto ({},{}) si pertenece al primer cuadrante'.format(j[0],j[1]))
  else:
    print('El punto ({},{}) no pertenece al primer cuadrante'.format(j[0],j[1]))
# Out:
# El punto (-68,51) no pertenece al primer cuadrante
# El punto (25,44) si pertenece al primer cuadrante
# El punto (98,-14) no pertenece al primer cuadrante
# El punto (16,-34) no pertenece al primer cuadrante
# El punto (-38,40) no pertenece al primer cuadrante
# El punto (-80,-70) no pertenece al primer cuadrante
# El punto (47,78) si pertenece al primer cuadrante
# El punto (-15,-23) no pertenece al primer cuadrante
# El punto (50,99) si pertenece al primer cuadrante
# El punto (17,-13) no pertenece al primer cuadrante
# El punto (64,-68) no pertenece al primer cuadrante
# El punto (-27,-59) no pertenece al primer cuadrante
# El punto (-70,44) no pertenece al primer cuadrante
# El punto (93,-83) no pertenece al primer cuadrante
# El punto (-56,45) no pertenece al primer cuadrante

# %% [markdown]
# # Ejercicio 6
# Crea un dataframe con 10 filas y 4 columnas. La primera columna se llamará word; la segunda, length;
# la tercera, vowels; y la última, consonants. La columna words contendrá las siguientes 10 palabras:
# “euro”, “diez” “algas”, “broma”, “cicuta”, “fatiga”, “nachos”, “jadeos”, “hazañas”, “boutique”. Las columnas
# length, vowels y consonants contendrán, respectivamente, la longitud, el total de vocales y el total de
# consonantes. Guarda el dataframe en la variable words.

# %%
def count_vowels(word):
  vocales = ['a', 'e', 'i', 'o', 'u']
  vowels = 0
  for character in word:
    if character in vocales:
      vowels += 1
  return vowels

# %%
Words = ['euro', 'diez', 'algas', 'broma', 'cicuta', 'fatiga', 'nachos','jadeos', 'hazañas', 'boutique']
length = [len(word) for word in Words]
words2characters= [list(word) for word in Words]
vowels = [count_vowels(word) for word in words2characters]
consonants = np.array(length) - np.array(vowels)
df = pd.DataFrame({'word':Words, 'length':length, 'vowels':vowels, 'consonants':consonants})
df
# Out:
#        word  length  vowels  consonants
# 0      euro       4       3           1
# 1      diez       4       2           2
# 2     algas       5       2           3
# 3     broma       5       2           3
# 4    cicuta       6       3           3
# 5    fatiga       6       3           3
# 6    nachos       6       2           4
# 7    jadeos       6       3           3
# 8   hazañas       7       3           4
# 9  boutique       8       5           3

# %% [markdown]
# # Ejercicio 7
# Muestra las 10 observaciones de words con el formato “La palabra {word} tiene {length} letras, de las cuales
# {vowels} son vocales y {consonants} consonantes”.

# %%
for i,j in df.iterrows():
  print('La palabra {} tiene {} letras, de las cuales {} son vocales y {} consonantes'.format(j[0], j[1], j[2], j[3]))
# Out:
# La palabra euro tiene 4 letras, de las cuales 3 son vocales y 1 consonantes
# La palabra diez tiene 4 letras, de las cuales 2 son vocales y 2 consonantes
# La palabra algas tiene 5 letras, de las cuales 2 son vocales y 3 consonantes
# La palabra broma tiene 5 letras, de las cuales 2 son vocales y 3 consonantes
# La palabra cicuta tiene 6 letras, de las cuales 3 son vocales y 3 consonantes
# La palabra fatiga tiene 6 letras, de las cuales 3 son vocales y 3 consonantes
# La palabra nachos tiene 6 letras, de las cuales 2 son vocales y 4 consonantes
# La palabra jadeos tiene 6 letras, de las cuales 3 son vocales y 3 consonantes
# La palabra hazañas tiene 7 letras, de las cuales 3 son vocales y 4 consonantes
# La palabra boutique tiene 8 letras, de las cuales 5 son vocales y 3 consonantes

# %% [markdown]
# # Ejercicio 8
# Muestra aquellas observaciones de words que tienen el mismo número de vocales y consonantes. Usa el
# método .query().

# %%
df.query('vowels == consonants')
# Out:
#      word  length  vowels  consonants
# 1    diez       4       2           2
# 4  cicuta       6       3           3
# 5  fatiga       6       3           3
# 7  jadeos       6       3           3

# %% [markdown]
# # Ejercicio 9
# Investiga el método .sort_values() para ordenar las observaciones según la longitud de las palabras en
# orden descendente.

# %%
df.sort_values(by=['length'], ascending=False)
# Out:
#        word  length  vowels  consonants
# 9  boutique       8       5           3
# 8   hazañas       7       3           4
# 4    cicuta       6       3           3
# 5    fatiga       6       3           3
# 6    nachos       6       2           4
# 7    jadeos       6       3           3
# 2     algas       5       2           3
# 3     broma       5       2           3
# 0      euro       4       3           1
# 1      diez       4       2           2

# %% [markdown]
# # Ejercicio 10
# Convierte la columna vowels a lista y, con sorted() ordénala de mayor a menor. Investiga para ello el
# método .tolist().

# %%
vowels= df['vowels'].tolist()
sorted(vowels, reverse=True)
# Out:
# [5, 3, 3, 3, 3, 3, 2, 2, 2, 2]
