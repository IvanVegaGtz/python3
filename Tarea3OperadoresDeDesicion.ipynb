# %% [markdown]
# Ejercicio 1
# Haz que un usuario introduzca un número real y evalúa si dicho número es positivo, negativo o cero. Devuelve
# por pantalla el resultado en cada caso.

# %%
numero=int(input("Inroduzca un número: "))
if numero == 0:
  print("El número es cero")
elif numero > 0:
  print("El número es positivo")
else:
  print("El número es negativo")
# Out:
# Inroduzca un número: -1
# El número es negativo

# %% [markdown]
# Ejercicio 2
# Haz que un usuario introduzca su nombre y evalúa con operadores if y else si dicho nombre tiene una
# longitud mayor a 10 caracteres o no. Devuelve por pantalla el resultado en cada caso.

# %%
nombre=input("Introduzca su nombre: ")
if len(nombre) > 10:
  print("Su nombre tiene más de 10 caracteres")
else:
  print("Su nombre tiene a lo más 10 caracteres")
# Out:
# Introduzca su nombre: joseeduardosanchez
# Su nombre tiene más de 10 caracteres

# %% [markdown]
# Ejercicio 3
# Realiza el ejercicio anterior con el uso del operador ternario.

# %%
nombre=input("Introduzca su nombre: ")
print("Su nombre tiene más de 10 caracteres") if len(nombre) > 10 else print("Su nombre tiene a lo más 10 caracteres")
# Out:
# Introduzca su nombre: ivan
# Su nombre tiene a lo más 10 caracteres

# %% [markdown]
# Ejercicio 4
# Haz que un usuario introduzca dos números enteros positivos. Comprueba si el primer número introducido
# por el usuario es mayor o igual que el segundo número introducido por el usuario. Devuelve por pantalla el
# resultado en cada caso.
# PISTA: Asegúrate de hacer uso de la función int() donde pertoque.

# %%
num1 = int(input("Introduzca el primer número: "))
num2 = int(input("Introduzca el segundo número: "))
if num1 >= num2:
  print("El primer número es mayor que el segundo")
else:
  print("El segundo número es mayor que el primero")
# Out:
# Introduzca el primer número: 90
# Introduzca el segundo número: 4
# El primer número es mayor que el segundo

# %% [markdown]
# Ejercicio 5
# Haz que un usuario introduzca dos números enteros positivos. Suponiendo que el primer número introducido
# por el usuario es mayor o igual al segundo número introducido por el usuario, comprueba que la división del
# primer número entre el segundo número es entera.
# En caso de la división ser entera, devuelve el cociente por pantalla e indica que la división en efecto es entera.
# En caso de la división no ser entera, devuelve el cociente y el resto por pantalla e indica que la división entre
# los dos números no es entera.

# %%
num1 = int(input("Introduzca el primer número: "))
num2 = int(input("Introduzca el segundo número: "))
if num1/num2 == num1//num2:
  print("La división es entera y el cociente es {}.".format(num1//num2))
else:
  print("La división no es entera, el cociente es {} y el residuo es {}.".format(num1//num2,num1%num2))
# Out:
# Introduzca el primer número: 2
# Introduzca el segundo número: 10
# La división no es entera, el cociente es 0 y el residuo es 2.

# %% [markdown]
# Ejercicio 6
# Fusiona lo hecho en los ejercicios 4 y 5 para que
# 1. Un usuario introduzca dos números enteros por pantalla.
# 2. Comprobar si el primer número es mayor o igual al segundo número introducido por el usuario. Devolver
# por pantalla en que caso nos encontramos.
# 3. Hacer la división entera pertinente en cada caso.
# 4. Si la división es entera, entonces devolver por pantalla el cociente e indicar que la división es entera.
# Si la división no es entera, entonces devolver por pantalla el cociente y el resto e indicar que la división
# realizada no es entera.

# %%
num1 = int(input("Introduzca el primer número: "))
num2 = int(input("Introduzca el segundo número: "))
if num1 >= num2:
  print("El primer número es mayor o igualque el segundo")
  if num1/num2 == num1//num2:
    print("La división es entera y el cociente es {}.".format(num1//num2))
  else:
    print("La división no es entera, el cociente es {} y el residuo es {}.".format(num1//num2,num1%num2))
else:
  print("El segundo número es mayor que el primero")
  if num1/num2 == num1//num2:
    print("La división es entera y el cociente es {}.".format(num1//num2))
  else:
    print("La división no es entera, el cociente es {} y el residuo es {}.".format(num1//num2,num1%num2))
# Out:
# Introduzca el primer número: 2
# Introduzca el segundo número: 20
# El segundo número es mayor que el primero
# La división no es entera, el cociente es 0 y el residuo es 2.

# %% [markdown]
# Ejercicio 7 Haz que un usuario introduzca dos números enteros positivos. Comprueba si el mayor es múltiplo del menor.
# Devuelve por pantalla el resultado en cada caso.

# %%
num1 = int(input("Introduzca el primer número: "))
num2 = int(input("Introduzca el segundo número: "))
if num1 >= num2:
  mayor=num1
  menor=num2
else:
  mayor=num2
  menor=num1
if mayor%menor == 0:
  print("El número mayor es múltiplo del menor")
else:
  print("El número mayor no es múltiplo del menor")
# Out:
# Introduzca el primer número: 10
# Introduzca el segundo número: 3
# El número mayor no es múltiplo del menor

# %% [markdown]
# Ejercicio 8
# Haz que un usuario introduzca una palabra y comprueba si dicha palabra empieza por mayúscula. Devuelve
# por pantalla el resultado en cada caso.

# %%
palabra=input("Introduzca una palabra: ")
palabra_capital=palabra.capitalize()
if palabra == palabra_capital:
  print("La palabra inicia con mayúscula")
else:
  print("La palabra no inicia con mayúscula")
# Out:
# Introduzca una palabra: hola
# La palabra no inicia con mayúscula

# %% [markdown]
# Ejercicio 9
# Haz un usuario introduza una letra y comprueba si se trata de una vocal. Si el usuario introduce un string
# de más de un carácter, infórmale de que no se puede procesar el dato, pues debe tener como máximo tamaño
# 1.
# PISTA: Convierte la letra introducida a minúsculas para tener que realizar menos comprobaciones

# %%
letra=input("Introduzca una letra: ")
letra=letra.lower()
if len(letra) > 1:
  print("No se puede procesar el dato")
else:
  if letra == 'a' or letra == 'e' or letra == 'i' or letra == 'o' or letra == 'u':
    print("La letra es una vocal")
  else:
    print("La letra es una consonante")
# Out:
# Introduzca una letra: u
# La letra es una vocal

# %% [markdown]
# Ejercicio 10
# haz que el usuario introduzca los valores de los coeficientes a, b, c. Con ello,
# 1. Comprueba que el coeficiente a es distinto de 0
# 2. En función del discriminante, calcula cuántas soluciones va a tener la ecuación de segundo grado
# ax2 + bx + c = 0.
# 3. Devuelve por pantalla el resultado en cada caso (tanto el número de soluciones en los números reales
# como el valor de éstas).
# PISTA: Para calcular la raíz cuadrada, vas a necesitar la función math.sqrt() de la librería math

# %%
from math import sqrt
a=int(input("Introduzca el valor para el coeficiente a: "))
b=int(input("Introduzca el valor para el coeficiente b: "))
c=int(input("Introduzca el valor para el coeficiente c: "))
if a!=0:
  dis=(b**2)-4*a*c
  if dis > 0:
    print("La ecuación tiene dos soluciones diferentes")
    sol1=(-b+sqrt(dis))/2*a
    sol2=(-b-sqrt(dis))/2*a
    print("Las soluciones son {} y {}".format(sol1,sol2))
  elif dis == 0:
    print("La ecuación tiene una única solución")
    sol=-b/(2*a)
    print("La solución es {} ".format(sol))
  else:
    print("La ecuación no tiene soluciones en los reales")

else:
  print("La ecuación no tiene solución")
# Out:
# Introduzca el valor para el coeficiente a: 1
# Introduzca el valor para el coeficiente b: 2
# Introduzca el valor para el coeficiente c: 1
# La ecuación tiene una única solución
# La solución es -1.0
